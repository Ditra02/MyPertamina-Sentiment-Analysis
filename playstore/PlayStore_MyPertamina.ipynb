# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## GET DATA

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.6-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.6

# %%
import pandas as pd
import numpy as np

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.dafturn.mypertamina',
    sleep_milliseconds=0,
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    filter_score_with=None
)

print(result)
# Out:
# [{'reviewId': '823acd73-2e78-4101-9276-6a711d0acd1b', 'userName': 'okta melani', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU4C2GyUCyaEmxjA01PuS2JK0ViPzpyYyyhf8CNGG0L1g', 'content': 'Aplikasi itu harusnya memudahkan, ini malah sebaliknya jadi menyulitkan, antrean udah lama pas giliran mau scan barcode aplikasinya eror, akhirnya gak bisa isi BBM... Jadi sia-sia saja ngantre lama2..', 'score': 1, 'thumbsUpCount': 191, 'reviewCreatedVersion': '4.3.0', 'at': datetime.datetime(2024, 3, 6, 14, 31, 8), 'replyContent': None, 'repliedAt': None, 'appVersion': '4.3.0'}, {'reviewId': '16856a42-e680-4a9d-9410-fa999528307f', 'userName': 'Kevin Figri', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW34BdrKwzcFGwhE4aHLiMSUQb0Bp1QmCctPPRHjYfv2A', 'content': 'Aplikasinya dalam 2 bulan terakhir ini mengecewakan sekali. Biasa nya kalau nopol sudah terdaftar saya ajukan banding menggunakan dokumen aslii terus sudah masuk email di setujui dan lanjut mendaftar lagi tetap ga bisa, padahal sudah disetujui dan sebelum sebelumnya aman aja. Mohon tingkatkan performa aplikasi ini jgn mempersulit yang ingin mendaftar dan verificator nya lama sekali bos biasa daftar brp jam kemudian beres sekarang mesti nunggu lama, gaguna . Mengecewakan!!!', 'score': 1, 'thumbsUpCount': 235, 'reviewCreatedVersion': '4.2.4', 'at': datetime.datetime(2024, 2, 20, 11, 24, 52), 'replyContent': None, 'repliedAt': None, 'appVersion': '4.2.4'}, {'reviewId': '7589f7ea-8a8d-42a6-9ec7-1a5f560c7486', 'userName': 'Romie Mocka', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWpa_81K_5alK848EJabelBvJJqWCx-5SWEWveomG-RFelk', 'content': 'Aplikasi sampah. Sudah setahun lebih gak ada improvement. Mau ubah data kendaraan juga tidak bisa. Udah gitu saat akses menu subsidi tepat juga sering error. Kalau gak becus bikin aplikasi mending gak usah pakai aplikasi aplikasian segala. Bikin mudah kagak, bikin repot doang yang ada...!!!!', 'score': 1, 'thumbsUpCount': 258, 'reviewCreatedVersion': '4.2.4', 'at': datetime.datetime(2024, 2, 17, 22, 23, 10), 'replyContent': None, 'repliedAt': None, 'appVersion': '4.2.4'}, {'reviewId': '04e2bcb0-51d8-4ce2-b0ed-643cb64fd364', 'userName': 'Azzam Muazzam', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUifTNwy44MA9H3SHbkKerhlYLoucqLYKBTj1e7Cv7dJ8U', 'content': 'Aplikasi tidak berguna dan membingungkan, pendaftaran sangat sulit dan berbelit-belit. Sudah mendapatkan fitur yang sesuai, selalu muncul nik sudah terdaftar tapi tidak ada solusi untuk sangahan. Mending dihapus saja', 'score': 1, 'thumbsUpCount': 15, 'reviewCreatedVersion': '4.3.0', 'at': datetime.datetime(2024, 3, 13, 7, 20, 20), 'replyContent': None, 'repliedAt': None, 'appVersion': '4.3.0'}, {'reviewId': '65728c82-922a-4132-8867-a14bbe89af94', 'userName': 'agny ikh', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWIfOKKgHkb0QL9W_obQ_3znf8w3WjELNyMeyOahuo0XQ', 'content': 'SUGGESTION: Pada halaman ketika mengisi biodata (on android) tidak bisa memilih Tahun dan bulan dengan langsung, melainkan harus menggeser ke bulan dan tahun yang dimau karena tanggalnya tenaik ke atas akibat muncul keboard pada handphone. pada web, alangkah baiknya untuk bisa mengupload foto dari galeri (untuk ktp,STNK, dll) daripada memfoto langsung KTP. Dan alangkah bagusnya jika verifikasi data untuk pendaftaran subsidi di percepat verifikasinya.', 'score': 3, 'thumbsUpCount': 3, 'reviewCreatedVersion': '4.3.0', 'at': datetime.datetime(2024, 3, 22, 6, 13, 10), 'replyContent': None, 'repliedAt': None, 'appVersion': '4.3.0'}, {'reviewId': '2b6f1400-fda9-41b5-9776-c2550cf43c19', 'userName': 'Mas Gie', 'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVWNLS1FQL-arzL3RrbeE4y5e3iZNOlQMcZOpasA3nnxLA', 'content': 'Yang Saya tau Aplikasi ini yang paling buruk selama hidupku di kwalitasnya NOL banget dibanding aplikasi lain , performanya sangat mengecewakan, sering error n lambat prosesnya. Mohon bagian IT Pertamina utk SEGERA DIPERBAIKI KWALUTAS APLIKASI ...

# %%
data = pd.DataFrame(np.array(result), columns=['review'])

data = data.join(pd.DataFrame(data.pop('review').tolist()))

data
# Out:
#                                  reviewId                 userName  \
# 0    823acd73-2e78-4101-9276-6a711d0acd1b              okta melani
# 1    16856a42-e680-4a9d-9410-fa999528307f              Kevin Figri
# 2    7589f7ea-8a8d-42a6-9ec7-1a5f560c7486              Romie Mocka
# 3    04e2bcb0-51d8-4ce2-b0ed-643cb64fd364            Azzam Muazzam
# 4    65728c82-922a-4132-8867-a14bbe89af94                 agny ikh
# ..                                    ...                      ...
# 194  3a650caa-a7fa-4429-8c7a-4cb98b90d6c4            Wahyu Purnomo
# 195  c9bd125a-19b2-49d3-b37f-ddcc4183792d            radika yulian
# 196  d2081df2-d31b-47f2-84f9-a4f6bcb18bfb  muhammad eka miryansyah
# 197  bc70df72-810e-4c31-892b-ebcd6276483a         Suminta Haryanto
# 198  b82b5dfe-d8d9-493b-b2bb-6af56b548c61             Ahmad Banyak
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a-/ALV-U...
# 4    https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                 ...
# 194  https://play-lh.googleusercontent.com/a-/ALV-U...
# 195  https://play-lh.googleusercontent.com/a-/ALV-U...
# 196  https://play-lh.googleusercontent.com/a-/ALV-U...
# 197  https://play-lh.googleusercontent.com/a/ACg8oc...
# 198  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                content  score  thumbsUpCount  \
# 0    Aplikasi itu harusnya memudahkan, ini malah se...      1            191
# 1    Aplikasinya dalam 2 bulan terakhir ini mengece...      1            235
# 2    Aplikasi sampah. Sudah setahun lebih gak ada i...      1            258
# 3    Aplikasi tidak berguna dan membingungkan, pend...      1             15
# 4    SUGGESTION: Pada halaman ketika mengisi biodat...      3              3
# ..                                                 ...    ...            ...
# 194  Kok verifikasi data diri terus kita ini sudah ...      1              0
# 195  Akhir akhir ini aplikasi ini tidak bisa login....      1              0
# 196  Mohon untuk diperbaiki , kalau masih gini belu...      1              1
# 197  Parah ini aplikasi masa gk bisa buka bercode, ...      1              0
# 198  Setiap mau bayar gak bisa di scan barcodenya j...      1              0
#
#     reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                  4.3.0 2024-03-06 14:31:08         None      None      4.3.0
# 1                  4.2.4 2024-02-20 11:24:52         None      None      4.2.4
# 2                  4.2.4 2024-02-17 22:23:10         None      None      4.2.4
# 3                  4.3.0 2024-03-13 07:20:20         None      None      4.3.0
# 4                  4.3.0 2024-03-22 06:13:10         None      None      4.3.0
# ..                   ...                 ...          ...       ...        ...
# 194                4.3.0 2024-03-22 06:37:27         None      None      4.3.0
# 195                4.2.4 2024-02-26 14:20:47         None      None      4.2.4
# 196                4.2.4 2024-02-23 10:33:03         None      None      4.2.4
# 197                4.2.4 2024-02-28 12:44:16         None      None      4.2.4
# 198                4.2.4 2024-02-29 10:12:15         None      None      4.2.4
#
# [199 rows x 11 columns]

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame(np.array(result), columns=['review'])

# Memisahkan kolom 'review' dan menggabungkannya kembali dengan hasil split
data = data.join(pd.DataFrame(data.pop('review').tolist()))

# Mengonversi kolom 'at' ke format datetime jika belum dalam format tersebut
data['at'] = pd.to_datetime(data['at'])

# Membuat filter untuk tanggal antara 25 Desember 2023 dan 25 Maret 2024
start_date = '2023-12-25'
end_date = '2024-03-25'
mask = (data['at'] >= start_date) & (data['at'] <= end_date)

# Memfilter dataframe dengan mask
filtered_data = data[mask]

# Menampilkan dataframe yang sudah difilter
print(filtered_data)
# Out:
#                                  reviewId                 userName  \
# 0    823acd73-2e78-4101-9276-6a711d0acd1b              okta melani
# 1    16856a42-e680-4a9d-9410-fa999528307f              Kevin Figri
# 2    7589f7ea-8a8d-42a6-9ec7-1a5f560c7486              Romie Mocka
# 3    04e2bcb0-51d8-4ce2-b0ed-643cb64fd364            Azzam Muazzam
# 4    65728c82-922a-4132-8867-a14bbe89af94                 agny ikh
# ..                                    ...                      ...
# 194  3a650caa-a7fa-4429-8c7a-4cb98b90d6c4            Wahyu Purnomo
# 195  c9bd125a-19b2-49d3-b37f-ddcc4183792d            radika yulian
# 196  d2081df2-d31b-47f2-84f9-a4f6bcb18bfb  muhammad eka miryansyah
# 197  bc70df72-810e-4c31-892b-ebcd6276483a         Suminta Haryanto
# 198  b82b5dfe-d8d9-493b-b2bb-6af56b548c61             Ahmad Banyak
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a-/ALV-U...
# 4    https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                 ...
# 194  https://play-lh.googleusercontent.com/a-/ALV-U...
# 195  https://play-lh.googleusercontent.com/a-/ALV-U...
# 196  https://play-lh.googleusercontent.com/a-/ALV-U...
# 197  https://play-lh.googleusercontent.com/a/ACg8oc...
# 198  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                content  score  thumbsUpCount  \
# 0    Aplikasi itu harusnya memudahkan, ini malah se...      1            191
# 1    Aplikasinya dalam 2 bulan terakhir ini mengece...      1            235
# 2    Aplikasi sampah. Sudah setahun lebih gak ada i...      1            258
# 3    Aplikasi tidak berguna dan membingungkan, pend...      1             15
# 4    SUGGESTION: Pada halaman ketika mengisi biodat...      3              3
# ..                                                 ...    ...            ...
# 194  Kok verifikasi data diri terus kita ini sudah ...      1              0
# 195  Akhir akhir ini aplikasi ini tidak bisa login....      1              0
# 196  Mohon untuk diperbaiki , kalau masih gini belu...      1              1
# 197  Parah ini aplikasi masa gk bisa buka bercode, ...      1              0
# 198  Setiap mau bayar gak bisa di scan barcodenya j...      1              0
#
#     reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                  4.3.0 2024-03-06 14:31:08         None      None      4.3.0
# 1                  4.2.4 2024-02-20 11:24:52         None      None      4.2.4
# 2                  4.2.4 2024-02-17 22:23:10         None      None      4.2.4
# 3                  4.3.0 2024-03-13 07:20:20         None      None      4.3.0
# 4                  4.3.0 2024-03-22 06:13:10         None      None      4.3.0
# ..                   ...                 ...          ...       ...        ...
# 194                4.3.0 2024-03-22 06:37:27         None      None      4.3.0
# 195                4.2.4 2024-02-26 14:20:47         None      None      4.2.4
# 196                4.2.4 2024-02-23 10:33:03         None      None      4.2.4
# 197                4.2.4 2024-02-28 12:44:16         None      None      4.2.4
# 198                4.2.4 2024-02-29 10:12:15         None      None      4.2.4
#
# [182 rows x 11 columns]

# %%
# Simpan dataframe yang sudah difilter ke dalam file CSV
filtered_data.to_csv('/content/drive/MyDrive/Magang/DDB/sentimen mypertamina playstore/filtered_data.csv', index=False)

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Magang/DDB/sentimen mypertamina playstore/filtered_data.csv')

# %%
df.head(25)
# Out:
#                                 reviewId             userName  \
# 0   823acd73-2e78-4101-9276-6a711d0acd1b          okta melani
# 1   16856a42-e680-4a9d-9410-fa999528307f          Kevin Figri
# 2   7589f7ea-8a8d-42a6-9ec7-1a5f560c7486          Romie Mocka
# 3   04e2bcb0-51d8-4ce2-b0ed-643cb64fd364        Azzam Muazzam
# 4   65728c82-922a-4132-8867-a14bbe89af94             agny ikh
# 5   2b6f1400-fda9-41b5-9776-c2550cf43c19              Mas Gie
# 6   f45ba482-da72-40fb-ba56-87dc5eb6ebf9                  rex
# 7   13a6e921-fd65-45f8-b967-6382231300c9       Retmono Legowo
# 8   1bac5874-85e7-4795-b74d-d8ab9ddbe7a9        Cepi Saepudin
# 9   c8a4980e-f8c0-416b-ad7a-fc5bc291f996      Yunita Fitriani
# 10  7c4546c8-b5a3-4065-ae0b-e5c100758af0           prada gara
# 11  68c41d9f-2a22-4547-87da-ec48213f6ab8          hadi winoto
# 12  695afbb6-6f71-483d-aa31-0b780302c8f4      faydion soedira
# 13  e40b7818-b8e0-470c-8565-89e7745c43a6  Bustanul Syaifuddin
# 14  e7dcbfc6-8d08-477d-beaf-72e6deb0ca38             udara ud
# 15  be338943-d69a-4bf6-88f6-9aa71dbf7fd2          Bani Rahayu
# 16  54b9b7e2-ae17-49c9-91ae-08648096daf1                YO LO
# 17  d1e19456-14bd-4dc9-b5c3-e6259d243bf6        yudi prasetyo
# 18  cdb19bb3-be4e-4bf7-a104-9a2f0b740193      Muhammad Indera
# 19  78fb6233-b698-486a-ad39-bdf7f169dd29           Vickyt M&G
# 20  a52adf70-e674-4ab4-82c0-cdb6484379ae        Ricky Maulana
# 21  6a95d49f-c10f-406e-9c11-0f982bdd8980  FADHIIL DHIYA'ULHAQ
# 22  551b0f78-7b84-487f-a21f-2707c1dcd74b              yeremia
# 23  f99e25f2-4782-4947-8ff8-e7bb6b9cec1b        Wahyu Purnomo
# 24  087c07a5-55c6-452c-8f6d-84835d1f1a8f       Jonsen Ginting
#
#                                             userImage  \
# 0   https://play-lh.googleusercontent.com/a-/ALV-U...
# 1   https://play-lh.googleusercontent.com/a-/ALV-U...
# 2   https://play-lh.googleusercontent.com/a-/ALV-U...
# 3   https://play-lh.googleusercontent.com/a-/ALV-U...
# 4   https://play-lh.googleusercontent.com/a-/ALV-U...
# 5   https://play-lh.googleusercontent.com/a-/ALV-U...
# 6   https://play-lh.googleusercontent.com/a-/ALV-U...
# 7   https://play-lh.googleusercontent.com/a-/ALV-U...
# 8   https://play-lh.googleusercontent.com/a-/ALV-U...
# 9   https://play-lh.googleusercontent.com/a-/ALV-U...
# 10  https://play-lh.googleusercontent.com/a/ACg8oc...
# 11  https://play-lh.googleusercontent.com/a-/ALV-U...
# 12  https://play-lh.googleusercontent.com/a-/ALV-U...
# 13  https://play-lh.googleusercontent.com/a-/ALV-U...
# 14  https://play-lh.googleusercontent.com/a/ACg8oc...
# 15  https://play-lh.googleusercontent.com/a-/ALV-U...
# 16  https://play-lh.googleusercontent.com/a-/ALV-U...
# 17  https://play-lh.googleusercontent.com/a-/ALV-U...
# 18  https://play-lh.googleusercontent.com/a/ACg8oc...
# 19  https://play-lh.googleusercontent.com/a-/ALV-U...
# 20  https://play-lh.googleusercontent.com/a-/ALV-U...
# 21  https://play-lh.googleusercontent.com/a-/ALV-U...
# 22  https://play-lh.googleusercontent.com/a-/ALV-U...
# 23  https://play-lh.googleusercontent.com/a-/ALV-U...
# 24  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                               content  score  thumbsUpCount  \
# 0   Aplikasi itu harusnya memudahkan, ini malah se...      1            175
# 1   Aplikasinya dalam 2 bulan terakhir ini mengece...      1            220
# 2   Aplikasi sampah. Sudah setahun lebih gak ada i...      1            239
# 3   Aplikasi tidak berguna dan membingungkan, pend...      1             10
# 4   SUGGESTION: Pada halaman ketika mengisi biodat...      3              0
# 5   Yang Saya tau Aplikasi ini yang paling buruk s...      1             36
# 6   Saya baru ingin memakai aplikasi ini dengan ha...      1             16
# 7   Masih banyak bug,tambah pembayaran dengan gopa...      1            156
# 8   Parah sistemnya, sering ngebug dan menu lainny...      1             39
# 9   Aplikasi payah luar biasa. Padahal sudah dafta...      1              0
# 10  unit telah terdaftar oleh penggunan sbelumnya,...      1             38
# 11  Hedeh.... Update versi terbaru (Feb 2024) mala...      2              3
# 12  Sepertinya negara bayar paket hemat buat bikin...      1             37
# 13  Pointnya kecil, untuk ngumpulin nya lama agar ...      2             39
# 14  Semakin lama semakin parah, update terbaru pun...      1             41
# 15  Sudah seringkali isi BBM pas bau bayar scan ba...      1              3
# 16  Payah, ga jelas peruntukannya. Awal² udh ngera...      1              2
# 17  Sebetulnya aplikasinya bagus, namun disayangka...      3              5
# 18  Bisa di bantu gak min, akun saya kok verifikas...      4              9
# 19  Ini bukannya memudahkan tapi menyulitkan, saya...      1              2
# 20  halooo, developernya tidur atau apa ini?? tiap...      1              6
# 21  Aplikasi terburuk pasti di korupsi, udh isi da...      1              0
# 22  Tidak bisa di hubungkan ke ovo sudah mencoba b...      1              2
# 23  Aplikasi koq ribet, sudah lama terverifikasi m...      1              0
# 24  Sangat kecewa dengan aplikasi my pertamina sek...      1              7
#
#    reviewCreatedVersion                   at  replyContent  repliedAt  \
# 0                 4.3.0  2024-03-06 14:31:08           NaN        NaN
# 1                 4.2.4  2024-02-20 11:24:52           NaN        NaN
# 2                 4.2.4  2024-02-17 22:23:10           NaN        NaN
# 3                 4.3.0  2024-03-13 07:20:20           NaN        NaN
# 4                 4.3.0  2024-03-22 06:13:10           NaN        NaN
# 5                 4.3.0  2024-03-03 03:07:28           NaN        NaN
# 6                 4.3.0  2024-03-12 00:10:31           NaN        NaN
# 7                 4.2.4  2024-01-10 11:15:33           NaN        NaN
# 8                 4.2.4  2024-02-19 06:31:35           NaN        NaN
# 9                 4.3.0  2024-03-23 20:41:25           NaN        NaN
# 10                4.2.4  2024-02-09 17:48:40           NaN        NaN
# 11                4.3.0  2024-03-12 23:17:46           NaN        NaN
# 12                4.2.4  2024-01-28 00:38:20           NaN        NaN
# 13                4.2.4  2024-01-10 05:59:04           NaN        NaN
# 14                4.2.4  2024-01-14 16:07:06           NaN        NaN
# 15                4.3.0  2024-03-16 12:20:54           NaN        NaN
# 16                4.3.0  2024-03-12 16:07:13           NaN        NaN
# 17                4.3.0  2024-03-08 11:31:08           NaN        NaN
# 18                4.3.0  2024-03-10 10:57:02           NaN        NaN
# 19                4.3.0  2024-03-14 15:59:32           NaN        NaN
# 20                4.3.0  2024-03-13 07:56:40           NaN        NaN
# 21                4.3.0  2024-03-19 03:02:47           NaN        NaN
# 22                4.3.0  2024-03-07 01:14:08           NaN        NaN
# 23                4.3.0  2024-03-24 03:22:39           NaN        NaN
# 24                4.3.0  2024-03-08 12:35:32           NaN        NaN
#
#    appVersion
# 0       4.3.0
# 1       4.2.4
# 2       4.2.4
# 3       4.3.0
# 4       4.3.0
# 5       4.3.0
# 6       4.3.0
# 7       4.2.4
# 8       4.2.4
# 9       4.3.0
# 10      4.2.4
# 11      4.3.0
# 12      4.2.4
# 13      4.2.4
# 14      4.2.4
# 15      4.3.0
# 16      4.3.0
# 17      4.3.0
# 18      4.3.0
# 19      4.3.0
# 20      4.3.0
# 21      4.3.0
# 22      4.3.0
# 23      4.3.0
# 24      4.3.0

# %%
df.columns
# Out:
# Index(['reviewId', 'userName', 'userImage', 'content', 'score',
#        'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent',
#        'repliedAt', 'appVersion'],
#       dtype='object')

# %%
df = df[['content','at']]
df.head()
# Out:
#                                              content                   at
# 0  Aplikasi itu harusnya memudahkan, ini malah se...  2024-03-06 14:31:08
# 1  Aplikasinya dalam 2 bulan terakhir ini mengece...  2024-02-20 11:24:52
# 2  Aplikasi sampah. Sudah setahun lebih gak ada i...  2024-02-17 22:23:10
# 3  Aplikasi tidak berguna dan membingungkan, pend...  2024-03-13 07:20:20
# 4  SUGGESTION: Pada halaman ketika mengisi biodat...  2024-03-22 06:13:10

# %%
df.shape
# Out:
# (185, 2)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.dropna()
df.head()
# Out:
#                                              content                   at
# 0  Aplikasi itu harusnya memudahkan, ini malah se...  2024-03-06 14:31:08
# 1  Aplikasinya dalam 2 bulan terakhir ini mengece...  2024-02-20 11:24:52
# 2  Aplikasi sampah. Sudah setahun lebih gak ada i...  2024-02-17 22:23:10
# 3  Aplikasi tidak berguna dan membingungkan, pend...  2024-03-13 07:20:20
# 4  SUGGESTION: Pada halaman ketika mengisi biodat...  2024-03-22 06:13:10

# %%
df.shape
# Out:
# (185, 2)

# %%
import re

# %%
def clean_twitter_text(text):
  # delete mention
  text = re.sub(r'@[A-Za-z0-9_]+', '', text)

  # deleting hashtag
  text = re.sub(r'#\w+', '', text)

  # delete retweet
  text = re.sub(r'RT[\s]+','', text)

  # delete url
  text = re.sub(r'https?://\S+', '', text)

  # delete character non-alfanumerik (hapus tanda baca)
  text = re.sub(r'[^A-Za-z ]', '', text)

  # hapus spasi berlebihan
  text = re.sub(r'\s+', ' ', text).strip()

  # hapus emoticon
  emoticon_pattern = r'[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F700-\U0001F77F\U0001F780-\U0001F7FF\U0001F800-\U0001F8FF\U0001F900-\U0001F9FF\U0001FA00-\U0001FA6F\U0001FA70-\U0001FAFF\U00002702-\U000027B0\U000024C2-\U0001F251\U0001f926-\U0001f937\U0001F1E0-\U0001F1FF\U0001F600-\U0001F64F\U0001F680-\U0001F6FF\U0001F700-\U0001F77F\U0001F780-\U0001F7FF\U0001F800-\U0001F8FF\U0001F900-\U0001F9FF\U0001FA00-\U0001FA6F\U0001FA70-\U0001FAFF\U00002702-\U000027B0\U000024C2-\U0001F251\U0001f926-\U0001f937\U00010000-\U0010ffff]+'
  text = re.sub(emoticon_pattern, '', text)

  # hapus tanda baca
  # text = re.sub("[^\w\s]", "", text)

  return text

df['content'] = df['content'].apply(clean_twitter_text)

# %%
df.head()
# Out:
#                                              content                   at
# 0  Aplikasi itu harusnya memudahkan ini malah seb...  2024-03-06 14:31:08
# 1  Aplikasinya dalam bulan terakhir ini mengecewa...  2024-02-20 11:24:52
# 2  Aplikasi sampah Sudah setahun lebih gak ada im...  2024-02-17 22:23:10
# 3  Aplikasi tidak berguna dan membingungkan penda...  2024-03-13 07:20:20
# 4  SUGGESTION Pada halaman ketika mengisi biodata...  2024-03-22 06:13:10

# %%
df['content'] = df['content'].str.lower()

# %%
df.head()
# Out:
#                                              content                   at
# 0  aplikasi itu harusnya memudahkan ini malah seb...  2024-03-06 14:31:08
# 1  aplikasinya dalam bulan terakhir ini mengecewa...  2024-02-20 11:24:52
# 2  aplikasi sampah sudah setahun lebih gak ada im...  2024-02-17 22:23:10
# 3  aplikasi tidak berguna dan membingungkan penda...  2024-03-13 07:20:20
# 4  suggestion pada halaman ketika mengisi biodata...  2024-03-22 06:13:10

# %% [markdown]
# ## Normalisasi

# %%
norm = {
    " yg ": "yang",
    " ganjar ": "",
    " prabowo ": "",
    " gak ": "tidak",
    " ga ": "tidak",
    " nggak ": "tidak",
    " bangetdari ": "banget dari",
    " prabowo ": "",
    " vibes ": "suasana",
    " klen ": "kalian",
    " tuk ": "untuk",
    " kalo ": "kalau",
    " kk ": "kakak",
    " alesan ": "alasan",
    " cth ": "contoh",
    " nanya ": "tanya",
    " tdk ": "tidak",
    " ktp ": "kartu tanda penduduk",
    " jg ": "juga",
    " kmrn ": "kemarin",
    " mending ": "lebih baik",
    " yth ": "kepada",
    " krg ": "kurang",
    " skrg ": "sekarang",
    " jgn ": "jangan",
    " sll ": "selalu",
    " gt ": "begitu",
    " wkwk ": "haha",
    " aja ": "saja",
    " dgn ": "dengan",
    " dst ": "dan seterusnya",
    " gtu ": "begitu",
    " bgt ": "banget",
    " gk ": "tidak",
    " dlm ": "dalam",
    " bgtu ": "begitu",
    " dpt ": "dapat",
    " d ": "di",
    " lg ": "lagi",
    " gpp ": "tidak apa-apa",
    " tp ": "tapi",
    " sm ": "sama",
    " gw ": "saya",
    " lu ": "kamu",
    " bkn ": "bukan",
    " km ": "kamu",
    " bsk ": "besok",
    " trs ": "terus",
    " brg ": "barang",
    " lgi ": "lagi",
    " bs ": "bisa",
    " emg ": "memang",
    " ad ": "ada",
    " krg ": "kurang",
    " gpp ": "tidak apa-apa",
    " bgt ": "banget",
    " y ": "ya",
    " dr ": "dari",
    " smp ": "sampai",
    " kyk ": "kayak",
    " smua ": "semua",
    " ky ": "kayak",
    " pdhl ": "padahal",
    " hrs ": "harus",
    " tp ": "tapi",
    " gpp ": "tidak apa-apa",
    " kyknya ": "kayaknya",
    " ntr ": "nanti",
    " td ": "tadi",
    " brp ": "berapa",
    " sih ": "sih",
    " lgs ": "langsung",
    " pd ": "pada",
    " skr ": "sekarang",
    " sll ": "selalu",
    " bgmn ": "bagaimana",
    " dmn ": "di mana",
    " krn ": "karena",
    " lwt ": "lewat",
    " nih ": "ini",
    " srg ": "sering",
    " n ": "dan",
    " hr ": "hari",
    " tmn ": "teman",
    " bwh ": "bawah",
    " sptny ": "sepertinya",
    " spti ": "seperti",
    " cm ": "cuma",
    " ms ": "masyarakat",
    " tnp ": "tanpa",
    " bbrp ": "beberapa",
    " skali ": "sangat",
    " mrk ": "mereka",
    " bngt ": "banget",
    " mr ": "mister",
    " bkn ": "bukan",
    " tmpt ": "tempat",
    " byk ": "banyak",
    " dlmnya ": "dalamnya",
    " kpd ": "kepada",
    " pgn ": "pengin",
    " krja ": "kerja",
    " dngn ": "dengan",
    " kl ": "kalau",
    " klw ": "kalau",
    " klwrg ": "keluarga",
    " kpn ": "kapan",
    " stlh ": "setelah",
    " dl ": "dulu",
    " nge ": "meng-",
    " yaa ": "ya",
    " gitu ": "begitu",
    " kmn ": "kemana",
    " sih ": "sih",
    " ko ": "kok",
    " bs ": "bisa",
    " d ": "di",
    " sini ": "di sini",
    " dpt ": "dapat",
    " kt ": "kata",
    " jdi ": "jadi",
    " mcm ": "macam",
    " shg ": "sehingga",
    " lbh ": "lebih",
    " tnpa ": "tanpa",
    " smpe ": "sampai",
    " tiap ": "setiap",
    " sesuai ": "sesuai",
    " jd ": "jadi",
    " tr ": "ter",
    " it ": "itu",
    " klh ": "kalah",
    " hny ": "hanya",
    " sblm ": "sebelum",
    " msh ": "masih",
    " tnp ": "tanpa",
    " wktu ": "waktu",
    " tkt ": "takut",
    " Ngelegg ": "Lambat",
    " Gaptek ": "Gagap teknologi",
    " Dong ": "Sungguh",
    " Nunggu ": "Menunggu",
    " Ribet ": "Rumit",
    " Dak jelas ": "Tidak jelas",
    " Tingkah ": "Berulah",
    " Ngeborong ": "Memborong",
    " Dsuruh ": "Disuruh",
    " Payah ": "Buruk",
    " Lawak ": "Lucu",
    " Emang ": "Memang",
    " Gampang ": "Mudah",
    " Emosi ": "Marah",
    " Ditunggu ": "Di tunggu",
    " Dulu ": "Dahulu",
    " Dongo ": "Bodoh",
    " Auto ": "Otomatis",
    " Ke-back ": "Kembali",
    " Dipertimbangkan ": "Dipertimbangkan",
    " Nutup ": "Menutup",
    " Ga guna ": "Tidak berguna",
    " Ga niat ": "Tidak niat",
    " Ga bisa ": "Tidak bisa",
    " Ga kepake ": "Tidak dipakai",
        " ke block ": "Diblokir",
    " Ribet-ribet ": "Rumit",
    " Nge-reset ": "Mereset",
    " Gede ": "Besar",
    " Nge-lemot ": "Lambat",
    " Nge-close ": "Tutup sendiri",
    " Gombal ": "Bohong",
    " Nge-hang ": "Macet",
    " Sssiiaallaann ": "Sangat lambat",
    " Siiaapp ": "Siap",
    " Tampilan makin kece ": "Tampilan semakin bagus",
    " Claim ": "Klaim",
    " afk ": "away from keyboard",
    " bae ": "before anyone else",
    " bruh ": "brother",
    " btw ": "by the way",
    " chill ": "relax",
    " cringe ": "embarrass",
    " fam ": "family",
    " finna ": "fixing to",
    " fleek ": "on point",
    " fomo ": "fear of missing out",
    " ftfy ": "fixed that for you",
    " gtg ": "got to go",
    " hmu ": "hit me up",
    " idk ": "I don't know",
    " ikr ": "I know, right?",
    " ily ": "I love you",
    " imho ": "in my humble opinion",
    " irl ": "in real life",
    " jk ": "just kidding",
    " kys ": "kill yourself (used sarcastically)",
    " lmao ": "laughing my ass off",
    " lit ": "excited",
    " lol ": "laughing out loud",
    " lowkey ": "not really",
    " no cap ": "no lie",
    " np ": "no problem",
    " ofc ": "of course",
    " omg ": "oh my God",
    " on fleek ": "on point",
    " op ": "overpowered",
    " otp ": "one true pairing",
    " plz ": "please",
    " prty ": "party",
    " rdy ": "ready",
    " salty ": "bitter",
    " smh ": "shaking my head",
    " srs ": "serious",
    " stfu ": "shut the f*ck up",
    " tbh ": "to be honest",
    " tfw ": "that feeling when",
    " thnx ": "thanks",
    " tldr ": "too long, didn't read",
    " tho ": "though",
    " tmw ": "tomorrow",
    " ttyl ": "talk to you later",
    " vibing ": "feeling good",
    " v chill ": "very relaxed",
    " wknd ": "weekend",
    " wtf ": "what the f*ck",
    " wtv ": "whatever",
    " yaaas ": "yes",
    " yolo ": "you only live once",
    " y u no ": "why don't you",
    " dunno ": "I Dont Know"
}

# %%
def normalisasi(str_text):
  for i in norm:
    str_text = str_text.replace(i, norm[i])
  return str_text

df['content'] = df['content'].apply(lambda x : normalisasi(x))
df.head(10)
# Out:
#                                              content                   at
# 0  aplikasi itu harusnya memudahkan ini malah seb...  2024-03-06 14:31:08
# 1  aplikasinya dalam bulan terakhir ini mengecewa...  2024-02-20 11:24:52
# 2  aplikasi sampah sudah setahun lebihtidakada im...  2024-02-17 22:23:10
# 3  aplikasi tidak berguna dan membingungkan penda...  2024-03-13 07:20:20
# 4  suggestion pada halaman ketika mengisi biodata...  2024-03-22 06:13:10
# 5  yang saya tau aplikasi ini yang paling buruk s...  2024-03-03 03:07:28
# 6  saya baru ingin memakai aplikasi ini dengan ha...  2024-03-12 00:10:31
# 7  masih banyak bugtambah pembayaran dengan gopay...  2024-01-10 11:15:33
# 8  parah sistemnya sering ngebug dan menu lainnya...  2024-02-19 06:31:35
# 9  aplikasi payah luar biasa padahal sudah daftar...  2024-03-23 20:41:25

# %% [markdown]
# ## Stopwords

# %%
more_stop_words = [
    "tidak",
    "a",
    "about",
    "above",
    "across",
    "after",
    "again",
    "against",
    "all",
    "almost",
    "alone",
    "along",
    "already",
    "also",
    "although",
    "always",
    "among",
    "an",
    "and",
    "another",
    "any",
    "are",
    "around",
    "as",
    "at",
    "away",
    "be",
    "because",
    "been",
    "before",
    "behind",
    "being",
    "below",
    "beneath",
    "beside",
    "between",
    "beyond",
    "both",
    "but",
    "by",
    "can",
    "cannot",
    "could",
    "couldn't",
    "day",
    "did",
    "didn't",
    "do",
    "does",
    "doesn't",
    "doing",
    "down",
    "during",
    "each",
    "either",
    "else",
    "enough",
    "even",
    "ever",
    "every",
    "everyone",
    "everything",
    "everywhere",
    "except",
    "few",
    "for",
    "from",
    "further",
    "get",
    "got",
    "had",
    "has",
    "have",
    "having",
    "he",
    "her",
    "here",
    "hers",
    "herself",
    "him",
    "himself",
    "his",
    "how",
    "however",
    "i",
    "if",
    "in",
    "into",
    "is",
    "it",
    "its",
    "itself",
    "just",
    "keep",
    "know",
    "known",
    "last",
    "later",
    "least",
    "less",
    "let",
    "like",
    "likely",
    "little",
    "long",
    "look",
    "made",
    "make",
    "making",
    "man",
    "many",
    "may",
    "me",
    "mean",
    "might",
    "more",
    "most",
    "much",
    "must",
    "my",
    "myself",
    "near",
    "need",
    "neither",
    "never",
    "new",
    "next",
    "no",
    "none",
    "nor",
    "not",
    "now",
    "of",
    "off",
    "often",
    "on",
    "once",
    "only",
    "or",
    "other",
    "ought",
    "our",
    "ours",
    "ourselves",
    "out",
    "over",
    "own",
    "past",
    "per",
    "perhaps",
    "please",
    "plus",
    "put",
    "rather",
    "really",
    "regarding",
    "said",
    "same",
    "saw",
    "say",
    "saying",
    "seems",
    "seen",
    "self",
    "sell",
    "sent",
    "she",
    "should",
    "since",
    "so",
    "some",
    "something",
    "sometimes",
    "somewhere",
    "soon",
    "still",
    "such",
    "sure",
    "take",
    "taken",
    "than",
    "that",
    "the",
    "their",
    "them",
    "themselves",
    "then",
    "there",
    "these",
    "they",
    "this",
    "those",
    "though",
    "through",
    "throughout",
    "to",
    "too",
    "toward",
    "towards",
    "under",
    "tidak",
    'ada', 'adalah', 'adanya', 'adapun', 'agak', 'agaknya', 'agar', 'akan', 'akankah', 'akhir', 'akhiri', 'akhirnya',
    'aku', 'akulah', 'amat', 'amatlah', 'anda', 'andalah', 'antar', 'antara', 'antaranya', 'apa', 'apaan', 'apabila',
    'apakah', 'apalagi', 'apatah', 'artinya', 'asal', 'asalkan', 'atas', 'atau', 'ataukah', 'ataupun', 'awal', 'awalnya',
    'bagaikan', 'bagaimana', 'bagaimanakah', 'bagaimanapun', 'bagi', 'bagian', 'bahkan', 'bahwa', 'bahwasanya', 'baik',
    'bakal', 'bakalan', 'balik', 'banyak', 'bapak', 'baru', 'bawah', 'beberapa', 'begini', 'beginian', 'beginikah',
    'beginilah', 'begitu', 'begitukah', 'begitulah', 'begitupun', 'bekerja', 'belakang', 'belakangan', 'belum',
    'belumlah', 'benar', 'benarkah', 'benarlah', 'berada', 'berakhir', 'berakhirlah', 'berakhirnya', 'berapa',
    'berapakah', 'berapalah', 'berapapun', 'berarti', 'berawal', 'berbagai', 'berdatangan', 'beri', 'berikan',
    'berikut', 'berikutnya', 'berjumlah', 'berkali-kali', 'berkata', 'berkehendak', 'berkeinginan', 'berkenaan',
    'berlainan', 'berlalu', 'berlangsung', 'berlebihan', 'bermacam', 'bermacam-macam', 'bermaksud', 'bermula',
    'bersama', 'bersama-sama', 'bersiap', 'bersiap-siap', 'bertanya', 'bertanya-tanya', 'berturut', 'berturut-turut',
    'bertutur', 'berujar', 'berupa', 'besar', 'betul', 'betulkah', 'biasa', 'biasanya', 'bila', 'bilakah', 'bisa',
    'bisakah', 'boleh', 'bolehkah', 'bolehlah', 'buat', 'bukan', 'bukankah', 'bukanlah', 'bukannya', 'bulan', 'bung',
    'cara', 'caranya', 'cukup', 'cukupkah', 'cukuplah', 'cuma', 'dahulu', 'dalam', 'dan', 'dapat', 'dari', 'daripada',
    'datang', 'dekat', 'demi', 'demikian', 'demikianlah', 'dengan', 'depan', 'di', 'dia', 'diakhiri', 'diakhirinya',
    'dialah', 'diantara', 'diantaranya', 'diberi', 'diberikan', 'diberikannya', 'dibuat', 'dibuatnya', 'didapat',
    'didatangkan', 'digunakan', 'diibaratkan', 'diibaratkannya', 'diingat', 'diingatkan', 'diinginkan', 'dijawab',
    'dijelaskan', 'dijelaskannya', 'dikarenakan', 'dikatakan', 'dikatakannya', 'dikerjakan', 'diketahui', 'diketahuinya',
    'dikira', 'dilakukan', 'dilalui', 'dilihat', 'dimaksud', 'dimaksudkan', 'dimaksudkannya', 'dimaksudnya', 'diminta',
    'dimintai', 'dimisalkan', 'dimulai', 'dimulailah', 'dimulainya', 'dimungkinkan', 'dini', 'dipastikan', 'diperbuat',
    'diperbuatnya', 'dipergunakan', 'diperkirakan', 'diperlihatkan', 'diperlukan', 'diperlukannya', 'dipersoalkan',
    'dipertanyakan', 'dipunyai', 'diri', 'dirinya', 'disampaikan', 'disebut', 'disebutkan', 'disebutkannya',
    'disini', 'disinilah', 'ditambahkan', 'ditandaskan', 'ditanya', 'ditanyai', 'ditanyakan', 'ditegaskan',
    'ditujukan', 'ditunjuk', 'ditunjuki', 'ditunjukkan', 'ditunjukkannya', 'ditunjuknya', 'dituturkan', 'dituturkannya',
    'diucapkan', 'diucapkannya', 'diungkapkan', 'dong', 'dua', 'dulu', 'empat', 'enggak', 'enggaknya', 'entah',
    'entahlah', 'guna', 'gunakan', 'hal', 'hampir', 'hanya', 'hanyalah', 'hari', 'harus', 'haruslah', 'harusnya',
    'hendak', 'hendaklah', 'hendaknya', 'hingga', 'ia', 'ialah', 'ibarat', 'ibaratkan', 'ibaratnya', 'ibu', 'ikut',
    'ingat', 'ingat-ingat', 'ingin', 'inginkah', 'inginkan', 'ini', 'inikah', 'inilah', 'itu', 'itukah', 'itulah',
    'jadi', 'jadilah', 'jadinya', 'jangan', 'jangankan', 'janganlah', 'jauh', 'jawab', 'jawaban', 'jawabnya',
    'jelas', 'jelaskan', 'jelaslah', 'jelasnya', 'jika', 'jikalau', 'juga', 'jumlah', 'jumlahnya', 'justru',
    'kala', 'kalau', 'kalaulah', 'kalaupun', 'kalian', 'kami', 'kamilah', 'kamu', 'kamulah', 'kan', 'kapan',
    'kapankah', 'kapanpun', 'karena']

# %%
# library buat mengubah kata-kata berimbuhan ke kata dasarnya dan menghapus dan, serta, dll
# !pip install sastrawi
# Out:
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1

# %%
import Sastrawi
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary


stop_words = StopWordRemoverFactory().get_stop_words()
stop_words.extend(more_stop_words)

new_array = ArrayDictionary(stop_words)
stop_words_remover_new = StopWordRemover(new_array)

def stopword(str_text):
  str_text = stop_words_remover_new.remove(str_text)
  return str_text

df['content'] = df["content"].apply(lambda x : stopword(x))
df
# Out:
#                                                content                   at
# 0    aplikasi harusnya memudahkan malah sebaliknya ...  2024-03-06 14:31:08
# 1    aplikasinya bulan terakhir mengecewakan sekali...  2024-02-20 11:24:52
# 2    aplikasi sampah setahun lebihtidakada improvem...  2024-02-17 22:23:10
# 3    aplikasi berguna membingungkan pendaftaran san...  2024-03-13 07:20:20
# 4    suggestion halaman mengisi biodata android bis...  2024-03-22 06:13:10
# ..                                                 ...                  ...
# 180  mau bayartidakbisa scan barcodenya jelek semua...  2024-02-29 10:12:15
# 181  aplikasi bermutu banget juga mau layanan terhe...  2024-02-25 01:45:36
# 182  gak di buka aplikasi nya habis update gimana s...  2024-03-15 08:06:41
# 183  apk ribet menyusahkan rakyat wajib punya barco...  2024-01-25 15:02:51
# 184  mengajukan keluhan sudah disetujui tetap bisa ...  2024-02-24 22:22:20
#
# [185 rows x 2 columns]

# %% [markdown]
# ## Tokenize

# %%
tokenized = df['content'].apply(lambda x : x.split())
tokenized
# Out:
# 0      [aplikasi, harusnya, memudahkan, malah, sebali...
# 1      [aplikasinya, bulan, terakhir, mengecewakan, s...
# 2      [aplikasi, sampah, setahun, lebihtidakada, imp...
# 3      [aplikasi, berguna, membingungkan, pendaftaran...
# 4      [suggestion, halaman, mengisi, biodata, androi...
#                              ...
# 180    [mau, bayartidakbisa, scan, barcodenya, jelek,...
# 181    [aplikasi, bermutu, banget, juga, mau, layanan...
# 182    [gak, di, buka, aplikasi, nya, habis, update, ...
# 183    [apk, ribet, menyusahkan, rakyat, wajib, punya...
# 184    [mengajukan, keluhan, sudah, disetujui, tetap,...
# Name: content, Length: 185, dtype: object

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

def stemming(text_cleaning):
  factory = StemmerFactory()
  stemmer = factory.create_stemmer()

  do = []

  for w in text_cleaning:
    dt = stemmer.stem(w)
    do.append(dt)

  d_clean = []
  d_clean = " ".join(do)

  print(d_clean)
  return d_clean

tokenized = tokenized.apply(stemming)
tokenized.to_csv("/content/drive/MyDrive/Magang/DDB/sentimen mypertamina playstore/HasilProcessingMypertamina.csv", index=False)
# Out:
# aplikasi harus mudah malah balik sulit antre udah lama pas gilir mau scan barcode aplikasi eror akhirnyatidakbisa isi bbm siasia ngantre lama
# aplikasi bulan akhir kecewa sekali nya nopol daftar aju banding guna dokumen asli terus masuk email tuju lanjut daftar tetaptidakbisa padahal tuju belum belum amansajamohon tingkat performa aplikasi inijanganmempersulit ingin daftar verificator nya lama sekali bos daftarberapajam kemudian beres sekarang mesti nunggu lama gaguna kecewa
# aplikasi sampah tahun lebihtidakada improvement mau ubah data kendara tidak udahbegitusaat akses menu subsidi tepat sering error kalautidakbecus bikin aplikasi mendingtidakusah pakai aplikasi aplikasi segala bikin mudah kagak bikin repot doang ada
# aplikasi guna bingung daftar sangat sulit berbelitbelit dapat fitur yangsesuaiselalu muncul nik daftar tidak solusi sangahanlebih baikdihapus
# suggestion halaman isi biodata android bisa pilih tahun bulan langsung harus geser bulan tahun mau tanggal tenaik atas akibat muncul keboard handphone web alangkah baik bisa mengupload foto galeri ktpstnk daripada foto langsungkartu tanda pendudukdan alangkah bagus verifikasi data daftar subsidi cepat verifikasi
# saya tau aplikasi yang paling buruk lama hidup kwalitasnya nol banget banding aplikasi performa sangat kecewa sering errordanlambat proses mohon bagianitupertamina utk segera baik kwalutas aplikasi tidak lebih gantiyanglebih pinter bidang itnya
# baru pakai aplikasi dengan harap transaksi lebih mudah alias cashless pas mau hubung metode bayar ewallet malahtidakbisa jadi salah muat laman padahal kodeone true pairingsudah masuk sms tolong baik aplikasi
# banyak bugtambah bayar gopay bisapadahal gopay aktifmau cek nohp edit kendara bisatanya halaman bantuanjuga tidak terlalu memuaskanjawaban ada sajatidak selesai permasalahanpantas banyakyangmemilih transaksi langsungdaripada lewat aplikasikarna nyata aplikasi sendiri banyak bug nyayg buat guna jadi kurang nyaman guna
# parah sistem sering ngebug menu lainnyatidakbisa dipake liat informasisajasering white screen connect bayar ovotidakbisa ganti plat kendaraantidakbisa hadeuh kayatidakserius nangani aplikasi pdahal punya perintah
# aplikasi payah luar padahal daftar verifikasi pas buka tau aplikasi minta update diupdate lah eh sekali update minta data itu sampe data kendara nunggu diverif astaga trus aplikasi layar homenya nama nuhin kata selamat nuhin siapa nuhin akun pernah pakai si nuhin sudah login hasil nama si nuhin muncul siapa nuhin
# unit daftar gun sbelumnya coba banding daftar ulang dapat email nopol diserutujui daftar ulangtapi tetep laku banding sudah kali tidakadaperubahanyang bener ajasedangkan barcodeyanglama sudahtidakbisa lagi pendaftaryanglamatidaktau siapa
# hedeh update versi baru feb malah hang terustidakbisa menu utama bolakbalik tunjuk menu kebangeten mbok yo dandan aplikasine nana pertamina
# seperti negara bayar paket hemat bikin aplikasi mypertamina ya semua isi bug makin kesini updatenya makin ngga pakai fitur fiturnya seperti koran buat baca berita
# point kecil ngumpulin nya lama tuker merchandise nya tahun upgrade hangus point boro tuker hangus duluan buat spesifikasi kendara roda sekali isi sedikit mana bisa tembus point continue
# makin lama makin parah update baru parah fitur cleam qr barcode error terus padahal fitur sangat penting aplikasi lahir mudah sulit
# seringkali isi bbm pas bau bayar scan barcode bisa klik bayar ulang kali sampe bilang sama tugas spbutidakada saldo langsung lah ku tunjuk saldo linkaja nya dong baik awal download aplikasi bisa pakai transaksi x itu bisa lagi proses bayar mana spbusekarangbanyakyangsdh terima debit bisa my pertamina sulit kaum cashless saya
# payahtidakjelas untuk udh ngerasa atas antrianyangpenuh pomkarenaada cashless makin kesini malah semua pom rata bilangtidakbisa pake aplikasi hadehh baik kebijaksanannya lokasi sumsel utama palembang
# aplikasi bagus sayang spbuyangtdk aktif guna pertaminadenganalasan sering offline utama malam pagi promoyangdi tawarkantidakbisa guna
# bantutidakmin akun kok verifikasi terus mau daftar nopol kendara tolak terus alas foto kendara tidaksesuaisudah di ganti dgsesuaisaran ambil foto malah foto stnk tidaksesuaidi ganti foto kendara tidaksesuailgi
# bukan mudah sulit daftar bolak tetep gagal gara gara foto kendara kurang lah nopol lihat lah foto sudah bagus sangat sekali pinjam hp teman kamera lebih bagus tetap gagal foto jelas mulu
# halooo developer tidur inisetiapkali buka aplikasi ganggu mulu udh pke wifi data error connection mutertidakjelas kasi supir truk baruyangmau daftar gabisa beli solar pas sdh bikin akun nunggu lama petinggi pertamina tau apa tau hasil duitnyasajakasian rakyat kecil khususnyayangkerja bawa truk milik prusahaan
# aplikasi buruk korupsi udh isi data sama data kendara malah tibatiba hilang hapus saat mau di buat ulang malah servernya bobrok yakinsayaini korupsi jelek banget
# bisa hubung ovo coba kali kali tetap jadi salah aplikasi perintah selalu buruk modal dikit napa untung dah pertamina wuuu sebel
# aplikasi koq ribet lama verifikasi malah data tolak alas stnk lah mudah konsumen malah sulit seperti biasasajajika kayak gin kerja
# sangat kecewa aplikasi pertamina sekarang nimendaftar buat qrbarkot selalu gagalselalu alas foto mobil tampak sampingdpan tak sesuai kekmna mksdya biar pas trus data sudah ferifikasi suruh edit datatrus nunggu perifikasi lagierror kyakya aplikasi niadmin tindak lanjut lah aplikasiya ni biar beres klo kyak gin kasihan lah orgyangbeli mobil sekenbeli mobiltidakad barkotmau daftar gagallll teruss
# kalau aplikasi susah tanggal lahir tahun ketik manualtidakbsa mundur manual bulan bulan tahun tahun konyol sekali hbs hbs upload foro error data nya hilang
# mau hubung ke metode bayar selalu jadi salah muat laman baik lahh cuma diem nonton
# aplikasi daftar subsidi tepat x gagal gilir daftarin punya temen x langsung kelas negara bikin aplikasikayakgini hmm telpon jugatidakada kami bisa bntu karna verifikasi sistem mendingtidakusah call center sekali kali nemu aplikasi parah ini
# aplikasi sampahkaga jelasmasalah verifikasi gambarsajasusah verifikasi gagal gara gara foto tidaksesuaipadahal udahsesuaicontoh emang aplikasitidakguna nyusahin orang aja
# aplikasi jelekbangetbukan mudah sulit udahdapatqr barcode banyak spbu tidak punya alat scan diinput manual sistem nya jgtidakbs kata bumn masak sistem kayak gin ajtidakbecus blm siap pakai sistem kayak ginilebih baikditunda kita ke jaman batulagiaj
# bad experiencetidakpraktis bolak minta upload berkas ngulang terus buang waktu perlu develop buat praktis dantidakribet
# nomor mati mau ganti nomor ndak akhir tanya cs biar bantu pusat nyata tetaptidakbisa malah suruh akun dan proses ribet tambah nomor akun baru sama dg nomor linksajaaplikasi sampah kalotidakdiwajibin daftartidakbakal download aplikasi kek gin
# bisa lagi kataini aplikasi bobroksystem bobrok semuabukannya mudah malah bingung aplikasitidakgunabobrok
# bingung anjur baik data poto mobil stnk diperbaikisesuaianjuran lebih x tetap tolak sudah punya aplikasi mypertamina yang saya laku mohon tunjuk nya
# susah payah antri tiba barcode buka padahal belum nya bisa sampai sekarang erorr rata aplikasi plat merah kalah sama aplikasi anak stm
# minta masyarakat sikitsikit online sikitsikit pake aplikasi aplikasiyangdikasih aplikasi sampah semua pakai guna sementaradata kendara hilangapk ngebugdownload barcode gabisa buatubah data apktidakrespon nantiyangdisalahi hp masyarakatkalauemg berat kali ngasih apkyangberguna udah balikansajatanpa perlu aplikasi
# usah instal aplikasi guna kota palembang operator non tunai nya selalu tidak ready tempat padahal kata spbu pertamina jam sebab antri operator tunai panjang ke jalan sebab macet celaka jadi hilang nyawa
# first time ngasih aplikasi bintang doang soal ngapain bikin aplikasikalaumau bayar pake mt pertamina ajatidakbisa udah nemu pom bensinyangkalo pas ngisi pertalitekalautak tanyain pake mt pertamina mas jawabannyatidakbisa error edc nya lah terus gaada edc nya lah kecewasihkarna emang download ni aplikasi biar gampang bayar nya karna tim cashlesstapinyatanya malah gaada guna moga lebih diperhatikanlagiterimakasih
# foto tidaksesuailah ban nya tidaksesuailah padahal kendaraanyangdi daftarsesuaistnk aplikasi ini ingin ikut anjur perintah aplikasi banyak eror
# aplikasi paling buruk aju data berharihari lolos verifikasi lebih hilang aplikasi seakanakan guna bagaimana bisa aktivitas data kami aju belum verifikasi selam berharihari
# sangatsangatsangattttt buruk aplikasi sering minta upgrade sering spbu nya sangat sedikityangbayar pakai dan pun banyak tutup isi alas nganguan
# lebih lagi kuota bbmyangsudah beli tampil aplikasi milik user hanya milik tugas spbu masa mobil hariyangsamatidakngisi bbm beli kuota habis pasti ulang oknum tugas spbu mohon baik keamanannnya tingkat
# aplikasi mudah malah sulit selalu bug klo blm clear knp realese aplikasi pengembangtidakada ubah
# lama previkasinya padahal masyarakat harus pakai qr mengidi bbm spbu daptar di aplikasi tapi hari di perivikasi di mudah biar program mypertamina jalan
# mempersulitt penggunatidakbisa ganti nomor isi bensin sulittidakada sinyaltapisuruh login suatu kebijakanyanganeh
# sumpah klo server siap jaman lbih modernminimaltidakmalah sulit penggunaapk indo klo mana adayangbner servernya lot pas btuh sering trouble
# lama verifikasi kendara nya kasi ini nunggu isi pertalite nga udah minggu mshsajaverifikasi terus capeeee dehhh
# aplikasi macam ini daftar konfirmasi hasil pas masuk pin bisa notice periksa hp lin poin
# fix hapus ni apktidakguna cuk guna upgrade la login la mana masuk nomor telpon dan pdahal di pom bensin baru mulu log log mulutidakberkualitas apk taii asuu
# makin kesini aplikasi makin sulit ketika antri bbm pertalite pas mw buka menu barcode subsidi malah eror dantidakbisa bayang uda antri lama mohon lah diperbaikijangansemakin ribet
# metode bayar baik lebih mudah hanya via linkaja transfer via bank lebih simpel makin flexible pasti makin yang mau guna terimakasih
# aplikasi bagustapiimplementasi lapang jalan alam ke pertamina isi peetamax kali ada erti aplikasi pertamina sangat sayang promo apps pertamina tidakbisadiklaim khusus daerah
# sblmnya sudahdapatcode qrtapisetelah update aplikasi kok malahtidakbisa dapat kode qr ya tidak menu komplain klik minta kode qr malah layarjadikosong
# aplikasi ribet mau download barcode ngga dan tambah kendara nunggu verifikasi lama sangat susah pembelikonsumen
# muncul pake google chrome padahal pakai chrome muncul tanya branda mulu terus link ke ovo gopayone true pairingmasuk aplikasi muncul halaman verifikasi harys muat ulang terus teteptidakbisa
# kasih bintang satu mau daftar bbm subsidi ribetnya minta ampuntidakbisa aplikasi website dari aplikasi malah kata user di temu aplikasi bumn buruk trus guna aplikasi trus foto itusayaudah fotoin semua lengkap eh nyata foto daftar hadeh
# uninstal lebih baiktp kasihanyangpunya kendara solaryangharus pakai barcodespbu sekarang alas mesin edc nyatidakada adayangnolak alas masuk rekening milik spbu catat pegawai kantor denganyangdi lapang akan pernah jalan baik hapussajaapk nya playstore tidak sulit orang klo memang ngotot arti memang main petinggisajasupaya ganti kendara listrik
# aplikasi goblkkemarinqr mshbisadipakesekarangmau isi katanyatidakbslagidipake mesti daftar ulang sdh daftar ulang mau lht qr malah error melulujadimau ngisi bensin mesti keliling cari spbuyangbs isi qr mypertamina tak bikin susah org gblok
# fitur subsiditepat claim kode qr pendaftaryangsdh daftar sudah terverifikasitidakbisa guna fitur claimnya padahal fitur sangat mudah si pegang kode qr kendara payah tingkat kualitasx tambah turun bintang tengah dulu min nnti klo dah bagus kasih bintang okeeeeyyyy
# ui nya cakep responsif beli pertamax selalu pake mypertamina sekarang nominal dapetin poin nya naikin untuk guna roda juga kumpul tukar hadiah malah reset duluan minimal exp point nya tahun biar sedikit reward
# updated paling jelek sekalikenapa fitur klaim barcode hilangkanpadahal ituyangsangat pentingniat updatetidaksiihtetepsajabugnya
# bnyak curang utama plattidaksesuai barcode seharusnyayangpajak kendara hidup sajayangbisa barcode bnyak kendaraanyangudhtidaklayak pakai kerja ngisi minyak untuk bisnis
# males pakai aplikasi coba bikin antri panjangsken pertamantidakberhasil suruh sken di dalm kantor berhasilpas liat riwayat x isi beli sekali bayar xperbaikan lahbelom semua spbu pakai aplikasi ini sekali buat motor beli rp spbu
# udh lama pake rasa beli bensin non tunai mau isi rasa nya lama tugas ribet lamban lebih cepatyangbayar tunai walaupun antri panjang tlng baik sistem biarbisacepat thx
# masuk masih spbu belum guna aplikasi dengan alas error ada jaring panjang lama antri pertamax nyata bayar tunai saran sayalebih baikdibenahi aplikasi kasih tunjuk kait aplikasi pertamina error konsumen kecewa
# ekonomi sulit tambah aplikasi mudah orang pertamina sendiri masyarakat malah buat mudah malah buat susah kebaya login itutidakbisa lihat bawah aplikasi bisa buat masyarakat mudah transaksi
# tlg baik masalah bayar guna kartu brikarenaselalu gagal terus transaksi hanyabisamenggunakan pembayarandenganlink aja
# install aplikasi uang simpan link bisa bayar pakai aplikasi hampir semua ada spbu bisa guna aplikasi mypertamina adayangbilang eror jaring lah payah banget sengaja simpan uang bensin ewallet biar bayar pakai mypertamina malah padatidakbisa spbu nya
# tambah kesini aplikasi sering errorr padahal selalu update aplikasi lho suka log sendiri info promo pas klik gagal muat apa iniyangsalah
# aplikasi pertamina sangat batu dong si baik sistemnyasoalnya terkadang tak munculvolume literdi aplikasialamat spbusudah adajumlah bayar waktu isi sempurnakurang volume literyangdi keluar terkadang ada
# harus mengupdate diupdate masalah mau lihat barqode eror memang kerja bangsa initidakadayangberes gimana mau masyarakat maju apk nyasajabegini gimana mauyanglainnya korupsi parah
# pertamina mantap makin canggih layan sdh bagus dg aplikasi nya bayar klo lgsg main tf dg bank apapuntidakpakai aplikasi lainjadilebih mudah sukses pertamina
# apa aplikasi klo pom masitidakbisa ngelaianin bayar pake apk mypertamin bagai alas edisi eror lah ganti sip lahh off line lah mau nerima kes doang
# w bingung pomyangga mau da berasalantidakbisa pake aplikasi ni kan mesin nya adabuat mobil doang kata notekalo jangan ambil karyawanyangudah tua umur nya terlalu tuatidakpaham dantidakngerti denga mesin pertamina
# sudah kali lalu beli bbm guna qrcodetapipembelian catat app mau tanya hal sebut saya tidak temu menu adu menu jenis
# sdh bulan qr codetidakbisa downloaduntungnya pnya screenshot qr codeyanglama masih isi bbm aplikasi buat mempermudahkalau sulit proses isi bbm hapus lahjangan nambah sulit rakyatyangsdh susah hidup
# sangat bantu saat bensin habis bisa cek lokasi spbu terdekatcuma masalah masih spbu belum guna aplikasi dan ada bisa bensin pertalite
# aplikasi bagus terap sangat kurangsebab spbuyangbelum aplikasi iniada spbuyangsudah layan sangat kurang sekali karena suka dahulu mobildibanding motorkami kendara motor pun guna aplikasi juga bayar jangandiabaikancontohdispbu demang kfc suka ada orang suka dahulu mobil saran kendara motoryangpakai aplikasi pertamina jangandiabaikam juga bayar nyatidakbayar layan tingkat
# aplikasi sering eror dapat bantu custdalampendaftaran sulit daftar subsidi tepat ada solusi sama sekali jelas buruk
# udah minggu lebih apk bisa selalu muat ulang halaman dapat muat dong min solusi nya apk bisa
# aplikasi sampaaah udah daftar susuh daftar ulang browser qr di aplikasitidakbisa buka
# mau dapet barcode susah bener mau beli spbu ditanyain barcode mau dapet barcodelewataplikasitidakbisa masuk mulu butut bener aplikasi
# kalo rating min sya ksihinieror terus nopol daftar yangtidakbisa lihat barcode lah mungkin cara sulit hidup
# syukur blm daftar sepenuh nyata keluh supir data tak di ubah auto uninstall
# metode bayar tidak bsa pakai ovo padahal pilih tpi di klik malah alih linkaja ngapain pilih metode bayar klo ujung cma pake linkaja
# tinggal nunggu verifikasi tahap dua lamanyaaaa udah minggu nyampesekarangblum jawab jga mh klo bikin barcodetidaksesusah
# aneh aplikasi pertamina tapitidakada harga produk kan beranda pajang harga pertamax pertalite jadi tahu update harganyasetiaphari
# banyak kurang kemarin sekarangtidakdi proses asa klo berani buka aplikasi berani kerja orang jaga aplikasi nya jam siapa tau daftar langsung prosesdengancepat
# aplikasi buruksetiapminggu update bsa kali di improvmenttidakada perunhan sama skli
# mau ganti metode bayar pake ovo malah error terus kirain error sekali kali tau nya error lama
# barcode bisa buka halaman error mudah isi solar sulit seperti lebih mudah akses barcode update aplikasi makin malah makin error
# aplikasitidakjelas suruh login mulu daftar ulang mulu bisa dipakenya aplikasi perintah gin amattidakbisa lebih bagus
# sudah pernah ferifikasi akun daftar kendara suruh ferifikasi mutersajadisitu terus
# pertamina nerapin atur pakai sistem barcode sistem sendiri siapkalaudi shellsihmudah bikin akun langsung dapet barcode
# isi pertalite kata nomor daftar bbm subsidipadahal aplikasi sukses terdaftarorangitunya payah
# tadi mau pindahdarishell aplikasi nya mayan ribet perbaikidarimetode bayar minimal pake virtual akunyangsupport maaf uninstall mau ke produk terima kasih
# wajib beli bbm scanbarcode aplikasi ribet pendaftaranperubahan data susah buka aplikasi eror bug
# blumadaminggu ganti hp barcode tiba error bisa beli solar subsidi padahal login akunyangsama apa aplikasi
# update aplikasi mau reset pin login muncul ingat tingkat kapasitas sistem padahal aplikasi masalah komplain email cs suruh hapus cache sampai ini malah ada balas lanjut
# nol guna bulan aplikasi teteptidakbisa isi di spbu bilang si tugas spbu bilang saja isi kok mas nunggu jam eee makintidakjelas malah mobil keluar
# usaha negara udah kaya milik peroranganawalnya isi solar pakai limit kuotasekarang ubah lagidalamsehari maksmal x isi solar padahal kuotamasihsisa bykdan isi solar jarak beda ratus kilo tetaptidakbisa sudah x isimakin sulit rakyat sendiri usah negara
# ga semua spbu awal prioritas guna pertamina kadang suruh antri jalur mtr bayar cash tugas spbu adayangngeselin klo guna aplikasi ramahlebih baikbaliklagipakai user cash lah di ngisi tank cukup kurang tidak bisa dikembalikanjadiuang cashkembalian
# aplikasi makin makin busukbarcodeyangudah trdaftartidakbisa dibukaapk inipembaruan malah buggmempersulit malah
# kacau bbm dah nipis mampir pom malah barcodetidakbisa buka error uninstall install dan masihsajaerror
# daftar proses verifikasi lebih kerja tidak pemberitahuan laku daftar ulang buang buang waktu
# bisa download barcode bugnya terlalu min mohon baik terimakasih
# yang baik bug tetepsajangga scan qr mesin edc spbu dari aplikasi ewallet langsung detect hasil minta lahkalauemang mau aplikasi rating bagus sama guna di coba scan qr di perhati promo macam makasih
# juga daftar waktu mau login malah terang salah pin nopepdhl bnrterussuruh tunggu mnt
# hbs update malah aplikasitidakbisa buka kasih bintang min
# app nya diperbaikin saat mau masuk barcode halaman web todak sedia sudah bulan mohon mudah pengunaanya
# udah kali baharu aplikasiyangbaru barcode tetap bisa didownload diprint sering logout sendiri
# apktidakjelas urgent nya pas hubung metode bayar malah jadi salah sampe di coba selalu kek gitu
# aplikasi sampahtidakgunasetiapdi butuh scan qr malahtidakrespon
# sdm belum pun guna program ini mau isi bensin gabisa pake qr code mau daftartidakbisa aplikasi malah ngbug siap sdm cukup buat aplikasi
# aplikasi sampah koktidakbisa pakai ubah kend kok ribet banget kyak ada main
# parah laman barcode error bisa guna antri lama buangbuang waktu
# apk susah buka sering ngebak mw daftar subsidi stempat udah waktu verifikasi ny lama abis adasajakendala inti ny apk susah org
# suruh update di update malah lancar malah error isi bug
# gabisa edit ubah kendaraantidakada fitur hapus akun langsung apknya nyesel downloadiniapk
# lihat orang kemarin transaksi pakai aplikasi mypertamina ribet banget scan qr code tugas pom nya tidak sedia qr code nya tiap mesin bayar biar lebih simple lg
# kenapa aplikasi fitur subsidi tepat dapat qr qodetidakbisa buka malah halaman web sedia
# update malahtidakbisa download qr codeproyek anyar isi dompet bikin aplikasi developer murah indonesia sedang baik
# hbs diupgrade malah susah dbukamasukin data unit punya sendirisajaselalu salah foto haduh mau gimana aplikasi
# terlalu baru terlalu syarat kami konsumen lebih bantu malah makin sulit dapat qr code
# aplikasi qr code error info cs email dm ig ada respon buka mudah malah nihil
# coba diupdatelagiini spbuyangtidak masuk aplikasi nya cari dimapstidakad
# dongjangancuma dibuatsajaini aplikasitapilama bgttidakdi verifikasi akun qt daftar buruk bgtmenyusahkan mah mudah
# satu minggu error hapus downloadlagitetep error cuma jadi hp
# ga semua spbu suport trnyata di perbaikiyatiap spbu nyaapalagi pertalite banyak gabisa
# gak aplikasi mau pulang acehtidakbisa isi pertalite barcode udah keluar eh sekarang tunggu verifikasi
# diupdate malah bisa klik mode bayar
# bisa pakai bug dj sistem pakai layar redmi note
# ada bintang nolsayaisi nol bintang nh aplikasikalo sulit harus mudah motonyabegituudh bnyk ulas buruk tapitidakada evaluasi baik bikin aturanyangharusnya tujuanya bagus bnyk mudhorotnya nh aplikasi sulit siapa shyangpunya usul aplikasi dn seterusnyatidaksadar wahai beliau tuh sulit
# belum siaptidakperlu lah buat aplikasi buat kalau nyata alih browser aplikasi lawak
# aplikasi dibenerin saya mau hubung ewallettidakbisaa bisaaa anehhh
# nunggu hari daftar ada verifikasi padahal bikin langsung cepat verifikasi lalu emailtolong evaluasi aplikasi
# parahiniaplikasi mau log intidakbisaterusmau isi solar nyata barcode nya udah lewat limit hari isi solar
# percuma apk mypertamina pombensin nya langka sedia layan sebut pom bensin tutup layan punya apk mypertamina tapitidakbisa guna
# aplikasi error coba hubung mypertamina lalu email jugatidakgunatidakada sama sekali
# apk nya sampah karyawan spb u nya nyolottidakngerti org suruh download udh download diatidakbisa daftar nya alibi nya didi sinisering erorr
# makin kesini operator merespon malah makin beranta tidak guna
# aplikasi diupdate mau loginsajakok susah
# ayooo pembayarantidakusa lalu linksajamasa download aplikasi bisa bayar lewat mypertamina
# plat nomor ganti bis isi bbmkarenaqrtidakmuncul
# amplikasi bobrokgabisa buka sama sekali semenjak baharu
# pendaftaranyangsangat lamatidakadayangbisa kerja yamemang sengaja rakyat sulit beli bbm
# ui makin bagus mudahtapikekurangannya bisa download qr di benah
# aplikasi tolol bug nya cok malah bikin ribet anjink pas udh update
# terlalu update lah bingung klo pas mau isi bbm posisi scrol subsidi tepat rubah trz bikin bingung habis update
# percuma download apk inisulit digunakanditolak pertamina banyak alasanharus pakai minimal lahtdk ini itulahlebih hapus
# aplikasi ini masa mau daftar bikin barcode susah nya minta ampun sangat sangat mengecewekankalaubelum siap mensejahterahkan rakyat sulit rakyat
# selamat pagi pas buka aplikasi masuk pas lihat kode selalu gagal bener aplikasi layak parah
# bikin barcod segitu susah nya mudah apatidakbisakita sopir jgan sulit
# buka qr code ndak bisatrus solusi gmn klo mau isi bbm klo ndak buka brcode aplikasi sampah hnya utk kpntingan tertentumerugikn rakyat kcil
# maaf pertamina di apk ada opsi rubah data data kendara kasihan guna ada barcode tidak pakai alas nomor kendara di barcode harussesuaidengan plat nomor baru padahal nama kendara suatu ada ubah data ganti milik ganti bijak perintah mohon terlalu sulit masyarakat yang aktifitas hari harus hubung kendara driver
# udah daftartidakbisa login salah terus aneh nomor hpyangterdaftar ulang xtidakbisa kocak
# tunggu verifikasidarihari ada tanda mau acctidakbisa buat hanya tunggu
# ktp password benar padahal udah cocoktidakjelas banget anj
# sangat kecewa saya aju hapus nopol lama adu banding data belum proses
# telah daftar aplikasi keluar sendiri kemudian bisa sangat buruk
# aplikasi kayak gin mau masuksajasusah pin selalu salah sengaja buatyanggampang pin kalautidakniat apkjangandi makan gaji butayangbuat apk
# bug nya bangetttt promo tiapdikliktidakbisa gembelbangetnih baik dlu lah
# sekitar lebih qr code subsidi tepat bisa bukamembuat dan guna bbm subsidi tepat lain ganggu mohon baik lebih manfaat
# banyak bug mau wajib isi bbm mbok di test lihat kode qr sendirisajasusahnya minta ampun
# suka keluar sendiri pas pilih barcode login ulanglagidan verifikasi ulang buat ribet
# pantkkkktidakbisa daftar subsidi salah jaring mulu halaman dapat muat tollollllll
# qr saldo sering potong kurang saya isi solar gimana klu ganti qr
# ada pilih bayar cash sering jadi operator salah klik pembayaranyangseharusnya bayar e wallet alhasil poin harus hangus
# masyaallahini apknyasudah updatetapitetap susah masuk kembalisudah hasil masuksering log dan ngulangindariawal terusbegitu kadang hari sudah loq lagi cerminitunyayg kurang canggih
# ko laman tukar poin voucher bbmtidakbisa muat tadi pake mypertamina biar bonus lumayan dikit dikit jugaa ternyatatidakbisa padahal sinyal kuat kuota tolong baik
# sering force update lah mau isi bensin mesti update contoh aplikasi mobile mandiri waktu sempat harus update aplikasi
# aplikasi mutu masuk akun bisa terang nik password salah akun pun kata daftar
# aplikasi moral minta verifikasi email login saya buka aplikasi email kembali aplikasi mypertamina malah ulang awal
# daftar bbm solar subsidi sangat sulit bpkb kendara ganti nopol dibpkb terterah ganti knpa proses bisa hub customernya jugatidakada direspon sangat sulit
# aplikasi kntl orang wajib pake link ajaklo orang gamau gimana harus akptkan linksajadulubaru metode bayar
# kok verifikasi data terus ini daftar
# akhir aplikasi tidak loginpadahal nik udah daftar punya akun
# mohon baik masih gin siap digital sering masalah nya
# cape lah daftar nya udah sulit aplikasi nyatidakbisa pake mau daftarinsajadi sulit
# parah aplikasi masatidakbisa buka bercode dong baik
# mau bayartidakbisa scan barcodenya jelek semua aplikasi pemerintahtidakpernah niat aplikasi
# aplikasi mutu banget juga mau layan henti terus
# gak di buka aplikasi nya habis update gimana solusi nya cara mendownload ulang qr code subsidi harus daftar ulang mohon jelas nya
# apk ribet susah rakyat wajib punya barcodetapidipersulit alas update lah browser baru lah internet lah apk tolol
# aju keluh sudah tuju tetap bisa lanjut daftar aneh sekali

# %% [markdown]
# ## translate

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/Magang/DDB/sentimen mypertamina playstore/HasilProcessingMypertamina.csv", encoding='latin1')
data.head(10)
# Out:
#                                              content
# 0  aplikasi harus mudah malah balik sulit antre u...
# 1  aplikasi bulan akhir kecewa sekali nya nopol d...
# 2  aplikasi sampah tahun lebihtidakada improvemen...
# 3  aplikasi guna bingung daftar sangat sulit berb...
# 4  suggestion halaman isi biodata android bisa pi...
# 5  saya tau aplikasi yang paling buruk lama hidup...
# 6  baru pakai aplikasi dengan harap transaksi leb...
# 7  banyak bugtambah bayar gopay bisapadahal gopay...
# 8  parah sistem sering ngebug menu lainnyatidakbi...
# 9  aplikasi payah luar padahal daftar verifikasi ...

# %%
# !pip install deep_translator
# Out:
# Collecting deep_translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep_translator) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2024.2.2)
# Installing collected packages: deep_translator
# Successfully installed deep_translator-1.11.4

# %%
from deep_translator import GoogleTranslator

def convert_eng(tweet):
    translator = GoogleTranslator(source='id', target='en')
    translation = translator.translate(tweet)
    return translation


data['tweet_english'] = data['content'].apply(convert_eng)

# %%
data.to_csv("/content/drive/MyDrive/Magang/DDB/sentimen mypertamina playstore/mypertaminaTranslate.csv")

# %%
data.head()
# Out:
#                                              content  \
# 0  aplikasi harus mudah malah balik sulit antre u...
# 1  aplikasi bulan akhir kecewa sekali nya nopol d...
# 2  aplikasi sampah tahun lebihtidakada improvemen...
# 3  aplikasi guna bingung daftar sangat sulit berb...
# 4  suggestion halaman isi biodata android bisa pi...
#
#                                        tweet_english
# 0  the application should be easy but instead it'...
# 1  Last month's application, very disappointed wi...
# 2  the application is rubbish for more than a yea...
# 3  application for confusion, the list is very di...
# 4  Suggestions for the Android biodata content pa...

# %%
data.shape
# Out:
# (185, 2)

# %% [markdown]
# ## labelling

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/Magang/DDB/sentimen mypertamina playstore/mypertaminaTranslate.csv", index_col=0)
data.shape
# Out:
# (185, 2)

# %%
# !pip install tweet-preprocessor
# !pip install textblob
# !pip install wordcloud
# !pip install nltk
# Out:
# Requirement already satisfied: tweet-preprocessor in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.2)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import preprocessor as p
from textblob import TextBlob
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data_tweet = list(data['tweet_english'])
polaritas = 0

status = []

total_positif = total_negatif = total_netral = total = 0

for i, tweet in enumerate(data_tweet):
    analysis = TextBlob(tweet)
    polaritas += analysis.polarity

    if analysis.sentiment.polarity > 0.0:
        total_positif += 1
        status.append('Positif')

    elif analysis.sentiment.polarity == 0.0:
        total_netral += 1
        status.append('Netral')

    else:
        total_negatif += 1
        status.append('Negatif')

    total += 1

# %%
print(f'Hasil Analisis Data:\nPositif = {total_positif}\nNetral = {total_netral}\nNegatif = {total_negatif}')
print(f'\nTotal Data : {total}')
# Out:
# Hasil Analisis Data:
# Positif = 77
# Netral = 21
# Negatif = 87
#
# Total Data : 185

# %%
data['klasifikasi'] = status
data.head(5)
# Out:
#                                              content  \
# 0  aplikasi harus mudah malah balik sulit antre u...
# 1  aplikasi bulan akhir kecewa sekali nya nopol d...
# 2  aplikasi sampah tahun lebihtidakada improvemen...
# 3  aplikasi guna bingung daftar sangat sulit berb...
# 4  suggestion halaman isi biodata android bisa pi...
#
#                                        tweet_english klasifikasi
# 0  the application should be easy but instead it'...     Positif
# 1  Last month's application, very disappointed wi...     Negatif
# 2  the application is rubbish for more than a yea...     Positif
# 3  application for confusion, the list is very di...     Positif
# 4  Suggestions for the Android biodata content pa...     Positif

# %% [markdown]
# ## Visualisasi

# %%
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud, STOPWORDS

def plot_cloud(wordcloud):
    plt.figure(figsize=(10, 8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

all_words = ' '.join([tweets for tweets in data['content']])

wordcloud = WordCloud(
    width=3000,
    height=2000,
    random_state=3,
    background_color='black',
    colormap='Blues_r',
    collocations = False,
    stopwords=STOPWORDS
).generate(all_words)

plot_cloud(wordcloud)

# %%
import seaborn as sns

sns.set_theme()

labels = ['Positif', 'Negatif', 'Netral']
counts = [total_positif, total_negatif, total_netral]

def show_bar_chart(labels, counts, title):
    fig, ax = plt.subplots(figsize=(8, 6))
    bars = ax.bar(labels, counts, color=['#2394f7', '#f72323', '#fac343'])

    for bar, count in zip(bars, counts):
        height = bar.get_height()

        print(bar.get_width())
        ax.annotate(f'{count}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords='offset points',
                    ha='center',
                    va='bottom')

    ax.grid(axis='y', linestyle='--', alpha=0.7)


    ax.set_xlabel('Sentimen')
    ax.set_ylabel('Jumlah')
    ax.set_title(title)

    plt.show()

show_bar_chart(labels, counts, "Distribusi Sentimen MyPertamina")
# Out:
# 0.8
# 0.8
# 0.8

# %% [markdown]
# ## Klasifikasi Sentimen

# %%
data
# Out:
#                                                content  \
# 0    aplikasi harus mudah malah balik sulit antre u...
# 1    aplikasi bulan akhir kecewa sekali nya nopol d...
# 2    aplikasi sampah tahun lebihtidakada improvemen...
# 3    aplikasi guna bingung daftar sangat sulit berb...
# 4    suggestion halaman isi biodata android bisa pi...
# ..                                                 ...
# 180  mau bayartidakbisa scan barcodenya jelek semua...
# 181    aplikasi mutu banget juga mau layan henti terus
# 182  gak di buka aplikasi nya habis update gimana s...
# 183  apk ribet susah rakyat wajib punya barcodetapi...
# 184  aju keluh sudah tuju tetap bisa lanjut daftar ...
#
#                                          tweet_english klasifikasi
# 0    the application should be easy but instead it'...     Positif
# 1    Last month's application, very disappointed wi...     Negatif
# 2    the application is rubbish for more than a yea...     Positif
# 3    application for confusion, the list is very di...     Positif
# 4    Suggestions for the Android biodata content pa...     Positif
# ..                                                 ...         ...
# 180  want to pay, can't scan the barcode, all gover...     Negatif
# 181  Very good quality application and will provide...     Positif
# 182  I can't open the application, it's finished up...      Netral
# 183  complicated apk is difficult people have to ha...     Negatif
# 184  If you have already complained, you can still ...     Negatif
#
# [185 rows x 3 columns]

# %%
dataset = data.drop(['content'], axis=1, inplace=False)
dataset = [tuple(x) for x in dataset.to_records(index=False)]

# %%
import random

set_positif = []
set_negatif = []
set_netral = []

for n in dataset:
    if (n[1] == 'Positif'):
        set_positif.append(n)
    elif (n[1] == 'Negatif'):
        set_positif.append(n)
    else:
        set_positif.append(n)

set_positif = random.sample(set_positif, k=int(len(set_positif)/2))
set_negatif = random.sample(set_negatif, k=int(len(set_negatif)/2))
set_netral = random.sample(set_netral, k=int(len(set_netral)/2))

train = set_positif + set_negatif + set_netral

train_set = []

for n in train:
    train_set.append(n)

# %%
from textblob.classifiers import NaiveBayesClassifier
c1 = NaiveBayesClassifier(train_set)
print('Akurasi Test: ', c1.accuracy(dataset))
# Out:
# Akurasi Test:  0.7783783783783784

# %%
# Labelling
data_tweet = list(data['tweet_english'])
polaritas = 0

total = 0

status = []
total_positif = total_negatif = total_netral = 0

for i, tweet in enumerate(data_tweet):
    analysis = TextBlob(tweet, classifier=c1)

    if analysis.classify() == 'Positif':
        total_positif += 1
    elif analysis.classify() == 'Negatif':
        total_netral += 1
    else:
        total_negatif += 1

    status.append(analysis.classify())
    total += 1

print(f'\nHasil Analisis Data\nPositif = {total_positif}\nNetral = {total_netral}\nNegatif = {total_negatif}')
print(f'\nTotal data = {total}')
# Out:
# Hasil Analisis Data
# Positif = 76
# Netral = 97
# Negatif = 12
#
# Total data = 185

# %%
status = pd.DataFrame({"Klasifikasi Bayes": status})
data['klasifikasi_bayes'] = status

# %%
import seaborn as sns

sns.set_theme()

labels = ['Positif', 'Negatif', 'Netral']
counts = [total_positif, total_negatif, total_netral]

def show_bar_chart(labels, counts, title):
    fig, ax = plt.subplots(figsize=(8, 6))
    bars = ax.bar(labels, counts, color=['#2394f7', '#f72323', '#fac343'])

    for bar, count in zip(bars, counts):
        height = bar.get_height()

        ax.annotate(f'{count}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords='offset points',
                    ha='center',
                    va='bottom')

    ax.grid(axis='y', linestyle='--', alpha=0.7)


    ax.set_xlabel('Sentimen')
    ax.set_ylabel('Jumlah')
    ax.set_title(title)

    plt.show()

show_bar_chart(labels, counts, "Distribusi Sentimen Mypertamina")

# %%
data
# Out:
#                                                content  \
# 0    aplikasi harus mudah malah balik sulit antre u...
# 1    aplikasi bulan akhir kecewa sekali nya nopol d...
# 2    aplikasi sampah tahun lebihtidakada improvemen...
# 3    aplikasi guna bingung daftar sangat sulit berb...
# 4    suggestion halaman isi biodata android bisa pi...
# ..                                                 ...
# 180  mau bayartidakbisa scan barcodenya jelek semua...
# 181    aplikasi mutu banget juga mau layan henti terus
# 182  gak di buka aplikasi nya habis update gimana s...
# 183  apk ribet susah rakyat wajib punya barcodetapi...
# 184  aju keluh sudah tuju tetap bisa lanjut daftar ...
#
#                                          tweet_english klasifikasi  \
# 0    the application should be easy but instead it'...     Positif
# 1    Last month's application, very disappointed wi...     Negatif
# 2    the application is rubbish for more than a yea...     Positif
# 3    application for confusion, the list is very di...     Positif
# 4    Suggestions for the Android biodata content pa...     Positif
# ..                                                 ...         ...
# 180  want to pay, can't scan the barcode, all gover...     Negatif
# 181  Very good quality application and will provide...     Positif
# 182  I can't open the application, it's finished up...      Netral
# 183  complicated apk is difficult people have to ha...     Negatif
# 184  If you have already complained, you can still ...     Negatif
#
#     klasifikasi_bayes
# 0             Positif
# 1             Negatif
# 2             Positif
# 3             Positif
# 4             Positif
# ..                ...
# 180           Negatif
# 181           Positif
# 182           Negatif
# 183           Negatif
# 184           Negatif
#
# [185 rows x 4 columns]

# %%
data_eval = [tuple(x) for x in data.to_records(index=False)]

for n in data_eval:
    if len(n) >= 4:
        if n[2] != n[3]:
            print(f'Text : {n[0]}\nClassifier: {n[2]}\nClassifier Bayes: {n[3]} \n')

    else:
        print('Tuple tidak memiliki cukup element')
# Out:
# Text : seringkali isi bbm pas bau bayar scan barcode bisa klik bayar ulang kali sampe bilang sama tugas spbutidakada saldo langsung lah ku tunjuk saldo linkaja nya dong baik awal download aplikasi bisa pakai transaksi x itu bisa lagi proses bayar mana spbusekarangbanyakyangsdh terima debit bisa my pertamina sulit kaum cashless saya
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : mau hubung ke metode bayar selalu jadi salah muat laman baik lahh cuma diem nonton
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : aplikasi sampahkaga jelasmasalah verifikasi gambarsajasusah verifikasi gagal gara gara foto tidaksesuaipadahal udahsesuaicontoh emang aplikasitidakguna nyusahin orang aja
# Classifier: Negatif
# Classifier Bayes: Positif
#
# Text : bad experiencetidakpraktis bolak minta upload berkas ngulang terus buang waktu perlu develop buat praktis dantidakribet
# Classifier: Negatif
# Classifier Bayes: Positif
#
# Text : first time ngasih aplikasi bintang doang soal ngapain bikin aplikasikalaumau bayar pake mt pertamina ajatidakbisa udah nemu pom bensinyangkalo pas ngisi pertalitekalautak tanyain pake mt pertamina mas jawabannyatidakbisa error edc nya lah terus gaada edc nya lah kecewasihkarna emang download ni aplikasi biar gampang bayar nya karna tim cashlesstapinyatanya malah gaada guna moga lebih diperhatikanlagiterimakasih
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : foto tidaksesuailah ban nya tidaksesuailah padahal kendaraanyangdi daftarsesuaistnk aplikasi ini ingin ikut anjur perintah aplikasi banyak eror
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : mempersulitt penggunatidakbisa ganti nomor isi bensin sulittidakada sinyaltapisuruh login suatu kebijakanyanganeh
# Classifier: Negatif
# Classifier Bayes: Positif
#
# Text : sumpah klo server siap jaman lbih modernminimaltidakmalah sulit penggunaapk indo klo mana adayangbner servernya lot pas btuh sering trouble
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : aplikasi bagustapiimplementasi lapang jalan alam ke pertamina isi peetamax kali ada erti aplikasi pertamina sangat sayang promo apps pertamina tidakbisadiklaim khusus daerah
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : muncul pake google chrome padahal pakai chrome muncul tanya branda mulu terus link ke ovo gopayone true pairingmasuk aplikasi muncul halaman verifikasi harys muat ulang terus teteptidakbisa
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : males pakai aplikasi coba bikin antri panjangsken pertamantidakberhasil suruh sken di dalm kantor berhasilpas liat riwayat x isi beli sekali bayar xperbaikan lahbelom semua spbu pakai aplikasi ini sekali buat motor beli rp spbu
# Classifier: Negatif
# Classifier Bayes: Positif
#
# Text : udh lama pake rasa beli bensin non tunai mau isi rasa nya lama tugas ribet lamban lebih cepatyangbayar tunai walaupun antri panjang tlng baik sistem biarbisacepat thx
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : ekonomi sulit tambah aplikasi mudah orang pertamina sendiri masyarakat malah buat mudah malah buat susah kebaya login itutidakbisa lihat bawah aplikasi bisa buat masyarakat mudah transaksi
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : sdh bulan qr codetidakbisa downloaduntungnya pnya screenshot qr codeyanglama masih isi bbm aplikasi buat mempermudahkalau sulit proses isi bbm hapus lahjangan nambah sulit rakyatyangsdh susah hidup
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : aplikasi sering eror dapat bantu custdalampendaftaran sulit daftar subsidi tepat ada solusi sama sekali jelas buruk
# Classifier: Negatif
# Classifier Bayes: Positif
#
# Text : aplikasi sampaaah udah daftar susuh daftar ulang browser qr di aplikasitidakbisa buka
# Classifier: Netral
# Classifier Bayes: Negatif
#
# Text : banyak kurang kemarin sekarangtidakdi proses asa klo berani buka aplikasi berani kerja orang jaga aplikasi nya jam siapa tau daftar langsung prosesdengancepat
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : aplikasitidakjelas suruh login mulu daftar ulang mulu bisa dipakenya aplikasi perintah gin amattidakbisa lebih bagus
# Classifier: Negatif
# Classifier Bayes: Positif
#
# Text : sudah pernah ferifikasi akun daftar kendara suruh ferifikasi mutersajadisitu terus
# Classifier: Netral
# Classifier Bayes: Negatif
#
# Text : pertamina nerapin atur pakai sistem barcode sistem sendiri siapkalaudi shellsihmudah bikin akun langsung dapet barcode
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : app nya diperbaikin saat mau masuk barcode halaman web todak sedia sudah bulan mohon mudah pengunaanya
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : aplikasi sampahtidakgunasetiapdi butuh scan qr malahtidakrespon
# Classifier: Negatif
# Classifier Bayes: Positif
#
# Text : sdm belum pun guna program ini mau isi bensin gabisa pake qr code mau daftartidakbisa aplikasi malah ngbug siap sdm cukup buat aplikasi
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : parah laman barcode error bisa guna antri lama buangbuang waktu
# Classifier: Negatif
# Classifier Bayes: Positif
#
# Text : lihat orang kemarin transaksi pakai aplikasi mypertamina ribet banget scan qr code tugas pom nya tidak sedia qr code nya tiap mesin bayar biar lebih simple lg
# Classifier: Negatif
# Classifier Bayes: Positif
#
# Text : terlalu baru terlalu syarat kami konsumen lebih bantu malah makin sulit dapat qr code
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : aplikasi qr code error info cs email dm ig ada respon buka mudah malah nihil
# Classifier: Negatif
# Classifier Bayes: Positif
#
# Text : coba diupdatelagiini spbuyangtidak masuk aplikasi nya cari dimapstidakad
# Classifier: Netral
# Classifier Bayes: Positif
#
# Text : diupdate malah bisa klik mode bayar
# Classifier: Netral
# Classifier Bayes: Positif
#
# Text : aplikasi dibenerin saya mau hubung ewallettidakbisaa bisaaa anehhh
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : aplikasi error coba hubung mypertamina lalu email jugatidakgunatidakada sama sekali
# Classifier: Netral
# Classifier Bayes: Positif
#
# Text : aplikasi diupdate mau loginsajakok susah
# Classifier: Negatif
# Classifier Bayes: Positif
#
# Text : ayooo pembayarantidakusa lalu linksajamasa download aplikasi bisa bayar lewat mypertamina
# Classifier: Netral
# Classifier Bayes: Positif
#
# Text : buka qr code ndak bisatrus solusi gmn klo mau isi bbm klo ndak buka brcode aplikasi sampah hnya utk kpntingan tertentumerugikn rakyat kcil
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : ktp password benar padahal udah cocoktidakjelas banget anj
# Classifier: Negatif
# Classifier Bayes: Positif
#
# Text : qr saldo sering potong kurang saya isi solar gimana klu ganti qr
# Classifier: Netral
# Classifier Bayes: Positif
#
# Text : ada pilih bayar cash sering jadi operator salah klik pembayaranyangseharusnya bayar e wallet alhasil poin harus hangus
# Classifier: Negatif
# Classifier Bayes: Positif
#
# Text : sering force update lah mau isi bensin mesti update contoh aplikasi mobile mandiri waktu sempat harus update aplikasi
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : kok verifikasi data terus ini daftar
# Classifier: Netral
# Classifier Bayes: Negatif
#
# Text : parah aplikasi masatidakbisa buka bercode dong baik
# Classifier: Positif
# Classifier Bayes: Negatif
#
# Text : gak di buka aplikasi nya habis update gimana solusi nya cara mendownload ulang qr code subsidi harus daftar ulang mohon jelas nya
# Classifier: Netral
# Classifier Bayes: Negatif

# %%
from wordcloud import WordCloud, STOPWORDS

def plot_cloud(wordcloud):
    plt.figure(figsize=(10, 8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

all_words = ' '.join([tweets for tweets in data['content']])

wordcloud = WordCloud(
    width=3000,
    height=2000,
    random_state=3,
    background_color='black',
    colormap='Blues_r',
    collocations = False,
    stopwords=STOPWORDS
).generate(all_words)

plot_cloud(wordcloud)

# %%
# data.to_csv('/content/drive/MyDrive/Magang/DDB/sentimen mypertamina playstore/final_appstore.csv')

# %%
x = 'asyafa ditra al hauna'
x = x.replace(' asyafa ', 'itu')
x
# Out:
# 'asyafa ditra al hauna'
